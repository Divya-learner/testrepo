# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Divya Jain</b>
# <br>Data Science

# %% [markdown]
# <i>I am interested in data science because I like playing with numbers and have been very strong with mathematics. I believe that I can use my strength in best possible way if I work in data science.</i>

# %% [markdown]
# ### This code is intended to make mathematical calculations.

# %%
23+23
# Out:
# 46

# %% [markdown]
# <b>We will do the following calculations:</b><br>
#
# <li>Addition</li>
# <li>Subtraction</li>
# <li>Multiplication</li>
# <li>Division</li>

# %% [markdown]
# <b>Also we will do the following:</b><br>
#
# <ol type = "1">
# <li>tables</li>
# <li>charts</li>
# </ol>

# %% [markdown]
# <b>This is the data for the students of Data Science class:</b><br>
#
# | S.No. | Name of the student | Location | Grade |
# | ----- | ----- | ----- | ----- |
# | 1 | Akshay | Dehradun | B |
# | 2 | Diksha | Delhi | C |
# | 3 | Abhishek | Indore | A |
# | 4 | Prachi | Darjeeling | B |
# | 5 | Abhilasha | Guwahati | A |
